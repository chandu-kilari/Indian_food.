# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/DA tasks/indian_food.csv')

# %%
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
df.iloc[0,0]
# Out:
# 'Balu shahi'

# %%
df.loc[0,'name']
# Out:
# 'Balu shahi'

# %%
df.iloc[0, 1]
# Out:
# 'Maida flour, yogurt, oil, sugar'

# %%
df.loc[62:67, 'name']
# Out:
# 62         Shrikhand
# 63        Sutar feni
# 64        Maach Jhol
# 65       Pork Bharta
# 66    Chak Hao Kheer
# 67             Galho
# Name: name, dtype: object

# %% [markdown]
# 1. Which state has the highest count of recipes?

# %%
df["cook_time"].idxmax()
# Out:
# 62

# %%
df1 = df.value_counts('state')
df1.loc['Maharashtra']
# Out:
# 30

# %%
df.value_counts('state').idxmax()
# Out:
# 'Gujarat'

# %%
df_count = df.groupby('state').count()
df_count['name'].idxmax()
# Out:
# 'Gujarat'

# %% [markdown]
# 2. What is the Average prep time of all the recipes?

# %%
df['prep_time'].mean()

# %% [markdown]
# 3. How many recipes are there in the dataset with a diet type “Non Vegetarian”?

# %%
df['diet'].value_counts()
# Out:
# diet
# vegetarian        226
# non vegetarian     29
# Name: count, dtype: int64

# %%
df['diet'].value_counts().get('non vegetarian')
# Out:
# 29

# %% [markdown]
# 4. What is the median cook time of recipes?

# %%
df['cook_time'].median()
# Out:
# 30.0

# %% [markdown]
# 5. What is the name of the recipe that has the longest cook time?

# %%
df['cook_time'].idxmax()
# Out:
# 62

# %%
df.loc[df['cook_time'].idxmax(),'name']
# Out:
# 'Shrikhand'

# %% [markdown]
# 6. What percentage of recipes is categorized as Dessert?

# %%
total_count = df['course'].count()
total_count
# Out:
# 255

# %%
dessert_count = (df['course'] == 'dessert').sum()
dessert_count
# Out:
# 85

# %%
(dessert_count/total_count)*100
# Out:
# 33.33333333333333

# %% [markdown]
# 7. How many recipes have cook time and prep time greater than 15 mins?

# %%
df[(df['prep_time'] > 15) & (df['cook_time'] > 15) ]['name'].count()
# Out:
# 84

# %% [markdown]
# 8. What are the ingredients present in the “singori” recipe?

# %%
df.loc[df[df['name'] == 'Singori'].index,'ingredients']
# Out:
# 17    Khoa, coconut, molu leaf
# Name: ingredients, dtype: object

# %% [markdown]
# 9. Find the correlation between cook time and prep time?

# %%
df['cook_time'].corr(df['prep_time'])
# Out:
# 0.14411325100222416

# %% [markdown]
# 10. What is the unique number of courses we have in the dataset?

# %%
df['course'].nunique()
# Out:
# 4
